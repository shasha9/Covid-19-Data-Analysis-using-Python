# %% [markdown]
# # COVID-19 in India

# %% [markdown]
# ### Importing the modules

# %%
# importing the required modules
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# Manipulating the default plot size
plt.rcParams['figure.figsize'] = 10, 12

# Disable warnings 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Scraping the datasets from Ministry of Health and Family Welfare website

# %%
from datetime import datetime
import re
import requests 
from bs4 import BeautifulSoup

# %%
# link for the site
link = 'https://www.mohfw.gov.in/'

req = requests.get(link)

soup = BeautifulSoup(req.content, "html.parser")

# %%
thead = soup.find_all('thead')[-1]
# print(thead)

head = thead.find_all('tr')
# print(head)

tbody = soup.find_all('tbody')[-1]
# print(tbody)

body = tbody.find_all('tr')
# print(body)

# %%
head_rows = []
body_rows = []

for tr in head:
    td = tr.find_all(['th', 'td'])
    row = [i.text for i in td]
    head_rows.append(row)

for tr in body:
    td = tr.find_all(['th', 'td'])
    row = [i.text for i in td]
    body_rows.append(row)

# %%
df_bs = pd.DataFrame(body_rows[:len(body_rows) - 6], columns = head_rows[0])      

df_bs.drop('S. No.', axis=1, inplace = True)

df_bs
# Out:
#              Name of State / UT Active Cases* Cured/Discharged/Migrated*  \
# 0   Andaman and Nicobar Islands             0                         33
# 1                Andhra Pradesh          1654                       2576
# 2             Arunachal Pradesh            44                          1
# 3                         Assam          1651                        498
# 4                         Bihar          2342                       2225
# 5                    Chandigarh            77                        222
# 6                  Chhattisgarh           633                        244
# 7            Dadar Nagar Haveli            13                          1
# 8                         Delhi         15311                      10315
# 9                           Goa           131                         65
# 10                      Gujarat          4901                      13003
# 11                      Haryana          1439                       2134
# 12             Himachal Pradesh           199                        189
# 13            Jammu and Kashmir          2202                       1086
# 14                    Jharkhand           464                        410
# 15                    Karnataka          3090                       1688
# 16                       Kerala           973                        712
# 17                       Ladakh            48                         48
# 18               Madhya Pradesh          2734                       5878
# 19                  Maharashtra         42224                      35156
# 20                      Manipur            91                         41
# 21                    Meghalaya            19                         13
# 22                      Mizoram            21                          1
# 23                     Nagaland            94                          0
# 24                       Odisha           996                       1604
# 25                   Puducherry            63                         36
# 26                       Punjab           344                       2069
# 27                    Rajasthan          2507                       7359
# 28                       Sikkim             3                          0
# 29                   Tamil Nadu         12700                      15762
# 30                    Telengana          1550                       1627
# 31                      Tripura           519                        173
# 32                  Uttarakhand           860                        344
# 33                Uttar Pradesh          3828                       5648
# 34                  West Bengal          4025                       2912
#
#    Deaths** Total Confirmed cases*
# 0         0                     33
# 1        73                   4303
# 2         0                     45
# 3         4                   2153
# 4        29                   4596
# 5         5                    304
# 6         2                    879
# 7         0                     14
# 8       708                  26334
# 9         0                    196
# 10     1190                  19094
# 11       24                   3597
# 12        5                    393
# 13       36                   3324
# 14        7                    881
# 15       57                   4835
# 16       14                   1699
# 17        1                     97
# 18      384                   8996
# 19     2849                  80229
# 20        0                    132
# 21        1                     33
# 22        0                     22
# 23        0                     94
# 24        8                   2608
# 25        0                     99
# 26       48                   2461
# 27      218                  10084
# 28        0                      3
# 29      232                  28694
# 30      113                   3290
# 31        0                    692
# 32       11                   1215
# 33      257                   9733
# 34      366                   7303

# %% [markdown]
# ## Cleaning the Data

# %%
df_India = df_bs.copy()

# today's date
now  = datetime.now()

# formatting date to month-day-year
df_India['Date'] = now.strftime("%m/%d/%Y") 

# addding 'Date' column to dataframe
df_India['Date'] = pd.to_datetime(df_India['Date'], format='%m/%d/%Y')

df_India.head()
# Out:
#             Name of State / UT Active Cases* Cured/Discharged/Migrated*  \
# 0  Andaman and Nicobar Islands             0                         33
# 1               Andhra Pradesh          1654                       2576
# 2            Arunachal Pradesh            44                          1
# 3                        Assam          1651                        498
# 4                        Bihar          2342                       2225
#
#   Deaths** Total Confirmed cases*       Date
# 0        0                     33 2020-06-07
# 1       73                   4303 2020-06-07
# 2        0                     45 2020-06-07
# 3        4                   2153 2020-06-07
# 4       29                   4596 2020-06-07

# %%
# removing extra characters from 'Name of State/UT' column

df_India['Name of State / UT'] = df_India['Name of State / UT'].str.replace('#', '')
df_India['Deaths**'] = df_India['Deaths**'].str.replace('#', '')

# %%
# latitude of the states
lat = {'Delhi':28.7041, 'Haryana':29.0588, 'Kerala':10.8505, 'Rajasthan':27.0238,
       'Telengana':18.1124, 'Uttar Pradesh':26.8467, 'Ladakh':34.2996, 'Tamil Nadu':11.1271,
       'Jammu and Kashmir':33.7782, 'Punjab':31.1471, 'Karnataka':15.3173, 'Maharashtra':19.7515,
       'Andhra Pradesh':15.9129, 'Odisha':20.9517, 'Uttarakhand':30.0668, 'West Bengal':22.9868, 
       'Puducherry': 11.9416, 'Chandigarh': 30.7333, 'Chhattisgarh':21.2787, 'Gujarat': 22.2587, 
       'Himachal Pradesh': 31.1048, 'Madhya Pradesh': 22.9734, 'Bihar': 25.0961, 'Manipur':24.6637, 
       'Mizoram':23.1645, 'Goa': 15.2993, 'Andaman and Nicobar Islands': 11.7401, 'Assam' : 26.2006, 
       'Jharkhand': 23.6102, 'Arunachal Pradesh': 28.2180, 'Tripura': 23.9408, 'Nagaland': 26.1584, 
       'Meghalaya' : 25.4670, 'Dadar Nagar Haveli' : 20.1809, 'Sikkim': 27.5330}

# longitude of the states
long = {'Delhi':77.1025, 'Haryana':76.0856, 'Kerala':76.2711, 'Rajasthan':74.2179,
        'Telengana':79.0193, 'Uttar Pradesh':80.9462, 'Ladakh':78.2932, 'Tamil Nadu':78.6569,
        'Jammu and Kashmir':76.5762, 'Punjab':75.3412, 'Karnataka':75.7139, 'Maharashtra':75.7139,
        'Andhra Pradesh':79.7400, 'Odisha':85.0985, 'Uttarakhand':79.0193, 'West Bengal':87.8550, 
        'Puducherry': 79.8083, 'Chandigarh': 76.7794, 'Chhattisgarh':81.8661, 'Gujarat': 71.1924, 
        'Himachal Pradesh': 77.1734, 'Madhya Pradesh': 78.6569, 'Bihar': 85.3131, 'Manipur':93.9063, 
        'Mizoram':92.9376, 'Goa': 74.1240, 'Andaman and Nicobar Islands': 92.6586, 'Assam' : 92.9376, 
        'Jharkhand': 85.2799, 'Arunachal Pradesh': 94.7278, 'Tripura': 91.9882, 'Nagaland': 94.5624,
        'Meghalaya' : 91.3662, 'Dadar Nagar Haveli' : 73.0169, 'Sikkim': 88.5122}

# add latitude column according to the 'Name of State / UT' column
df_India['Latitude'] = df_India['Name of State / UT'].map(lat)

# add longitude column according to the 'Name of State / UT' column
df_India['Longitude'] = df_India['Name of State / UT'].map(long)

df_India.head()
# Out:
#             Name of State / UT Active Cases* Cured/Discharged/Migrated*  \
# 0  Andaman and Nicobar Islands             0                         33
# 1               Andhra Pradesh          1654                       2576
# 2            Arunachal Pradesh            44                          1
# 3                        Assam          1651                        498
# 4                        Bihar          2342                       2225
#
#   Deaths** Total Confirmed cases*       Date  Latitude  Longitude
# 0        0                     33 2020-06-07   11.7401    92.6586
# 1       73                   4303 2020-06-07   15.9129    79.7400
# 2        0                     45 2020-06-07   28.2180    94.7278
# 3        4                   2153 2020-06-07   26.2006    92.9376
# 4       29                   4596 2020-06-07   25.0961    85.3131

# %%
# renaming the columns
df_India = df_India.rename(columns = {'Cured/Discharged/Migrated*' :'Cured', 
                                       'Total Confirmed cases*': 'Confirmed',
                                       'Deaths**': 'Deaths',
                                       'Active Cases*': 'Active'})

df_India = df_India.rename(columns = {'Name of State / UT': 'State/UT'})

df_India.head()
# Out:
#                       State/UT Active Cured Deaths Confirmed       Date  \
# 0  Andaman and Nicobar Islands      0    33      0        33 2020-06-07
# 1               Andhra Pradesh   1654  2576     73      4303 2020-06-07
# 2            Arunachal Pradesh     44     1      0        45 2020-06-07
# 3                        Assam   1651   498      4      2153 2020-06-07
# 4                        Bihar   2342  2225     29      4596 2020-06-07
#
#    Latitude  Longitude
# 0   11.7401    92.6586
# 1   15.9129    79.7400
# 2   28.2180    94.7278
# 3   26.2006    92.9376
# 4   25.0961    85.3131

# %%
# unique state names
df_India['State/UT'].unique()
# Out:
# array(['Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadar Nagar Haveli', 'Delhi', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Ladakh', 'Madhya Pradesh', 'Maharashtra',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha',
#        'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu',
#        'Telengana', 'Tripura', 'Uttarakhand', 'Uttar Pradesh',
#        'West Bengal'], dtype=object)

# %%
# number of missing values 
df_India.isna().sum()
# Out:
# State/UT     0
# Active       0
# Cured        0
# Deaths       0
# Confirmed    0
# Date         0
# Latitude     0
# Longitude    0
# dtype: int64

# %%
# number of unique values 
df_India.nunique()
# Out:
# State/UT     35
# Active       35
# Cured        32
# Deaths       24
# Confirmed    34
# Date          1
# Latitude     35
# Longitude    31
# dtype: int64

# %%
# converting date column to datetime datatype
df_India['Date'] = pd.to_datetime(df_India['Date'])

df_India.head()
# Out:
#                       State/UT Active Cured Deaths Confirmed       Date  \
# 0  Andaman and Nicobar Islands      0    33      0        33 2020-06-07
# 1               Andhra Pradesh   1654  2576     73      4303 2020-06-07
# 2            Arunachal Pradesh     44     1      0        45 2020-06-07
# 3                        Assam   1651   498      4      2153 2020-06-07
# 4                        Bihar   2342  2225     29      4596 2020-06-07
#
#    Latitude  Longitude
# 0   11.7401    92.6586
# 1   15.9129    79.7400
# 2   28.2180    94.7278
# 3   26.2006    92.9376
# 4   25.0961    85.3131

# %%
# rename some of the state/UT names

df_India['State/UT'].replace('Chattisgarh', 'Chhattisgarh', inplace = True)
df_India['State/UT'].replace('Pondicherry', 'Puducherry', inplace = True)

# %%
# changing the datatype of some of the columns
df_India[['Active', 'Cured', 'Deaths', 'Confirmed', 'Latitude', 'Longitude']] = df_India[['Active', 'Cured', 'Deaths', 'Confirmed', 'Latitude', 'Longitude']].apply(pd.to_numeric)

# %%
df_India.describe()
# Out:
#              Active         Cured       Deaths     Confirmed   Latitude  \
# count     35.000000     35.000000    35.000000     35.000000  35.000000
# mean    3078.571429   3259.228571   189.771429   6527.571429  23.357097
# std     7571.401826   6747.666416   521.575052  14632.261391   6.463139
# min        0.000000      0.000000     0.000000      3.000000  10.850500
# 25%       84.000000     44.500000     0.000000    115.500000  19.966200
# 50%      860.000000    498.000000     8.000000   1699.000000  23.940800
# 75%     2424.500000   2400.500000    93.000000   4715.500000  27.875500
# max    42224.000000  35156.000000  2849.000000  80229.000000  34.299600
#
#        Longitude
# count  35.000000
# mean   82.070229
# std     7.255625
# min    71.192400
# 25%    76.423650
# 50%    79.019300
# 75%    88.183600
# max    94.727800

# %% [markdown]
# ### Final dataframe

# %%
df_India
# Out:
#                        State/UT  Active  Cured  Deaths  Confirmed       Date  \
# 0   Andaman and Nicobar Islands       0     33       0         33 2020-06-07
# 1                Andhra Pradesh    1654   2576      73       4303 2020-06-07
# 2             Arunachal Pradesh      44      1       0         45 2020-06-07
# 3                         Assam    1651    498       4       2153 2020-06-07
# 4                         Bihar    2342   2225      29       4596 2020-06-07
# 5                    Chandigarh      77    222       5        304 2020-06-07
# 6                  Chhattisgarh     633    244       2        879 2020-06-07
# 7            Dadar Nagar Haveli      13      1       0         14 2020-06-07
# 8                         Delhi   15311  10315     708      26334 2020-06-07
# 9                           Goa     131     65       0        196 2020-06-07
# 10                      Gujarat    4901  13003    1190      19094 2020-06-07
# 11                      Haryana    1439   2134      24       3597 2020-06-07
# 12             Himachal Pradesh     199    189       5        393 2020-06-07
# 13            Jammu and Kashmir    2202   1086      36       3324 2020-06-07
# 14                    Jharkhand     464    410       7        881 2020-06-07
# 15                    Karnataka    3090   1688      57       4835 2020-06-07
# 16                       Kerala     973    712      14       1699 2020-06-07
# 17                       Ladakh      48     48       1         97 2020-06-07
# 18               Madhya Pradesh    2734   5878     384       8996 2020-06-07
# 19                  Maharashtra   42224  35156    2849      80229 2020-06-07
# 20                      Manipur      91     41       0        132 2020-06-07
# 21                    Meghalaya      19     13       1         33 2020-06-07
# 22                      Mizoram      21      1       0         22 2020-06-07
# 23                     Nagaland      94      0       0         94 2020-06-07
# 24                       Odisha     996   1604       8       2608 2020-06-07
# 25                   Puducherry      63     36       0         99 2020-06-07
# 26                       Punjab     344   2069      48       2461 2020-06-07
# 27                    Rajasthan    2507   7359     218      10084 2020-06-07
# 28                       Sikkim       3      0       0          3 2020-06-07
# 29                   Tamil Nadu   12700  15762     232      28694 2020-06-07
# 30                    Telengana    1550   1627     113       3290 2020-06-07
# 31                      Tripura     519    173       0        692 2020-06-07
# 32                  Uttarakhand     860    344      11       1215 2020-06-07
# 33                Uttar Pradesh    3828   5648     257       9733 2020-06-07
# 34                  West Bengal    4025   2912     366       7303 2020-06-07
#
#     Latitude  Longitude
# 0    11.7401    92.6586
# 1    15.9129    79.7400
# 2    28.2180    94.7278
# 3    26.2006    92.9376
# 4    25.0961    85.3131
# 5    30.7333    76.7794
# 6    21.2787    81.8661
# 7    20.1809    73.0169
# 8    28.7041    77.1025
# 9    15.2993    74.1240
# 10   22.2587    71.1924
# 11   29.0588    76.0856
# 12   31.1048    77.1734
# 13   33.7782    76.5762
# 14   23.6102    85.2799
# 15   15.3173    75.7139
# 16   10.8505    76.2711
# 17   34.2996    78.2932
# 18   22.9734    78.6569
# 19   19.7515    75.7139
# 20   24.6637    93.9063
# 21   25.4670    91.3662
# 22   23.1645    92.9376
# 23   26.1584    94.5624
# 24   20.9517    85.0985
# 25   11.9416    79.8083
# 26   31.1471    75.3412
# 27   27.0238    74.2179
# 28   27.5330    88.5122
# 29   11.1271    78.6569
# 30   18.1124    79.0193
# 31   23.9408    91.9882
# 32   30.0668    79.0193
# 33   26.8467    80.9462
# 34   22.9868    87.8550

# %%
# complete data info
df_India.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 8 columns):
# State/UT     35 non-null object
# Active       35 non-null int64
# Cured        35 non-null int64
# Deaths       35 non-null int64
# Confirmed    35 non-null int64
# Date         35 non-null datetime64[ns]
# Latitude     35 non-null float64
# Longitude    35 non-null float64
# dtypes: datetime64[ns](1), float64(2), int64(4), object(1)
# memory usage: 2.3+ KB

# %%
# simply copying the dataframe
df = df_India.copy()

# %% [markdown]
# ## Analysing COVID 19 Cases in India

# %%
total_cases = df['Confirmed'].sum()
print('Total confirmed cases of COVID 19 across India till date are:', total_cases)
# Out:
# Total confirmed cases of COVID 19 across India till date are: 228465

# %%
# Highlighting the dataframe

df_temp = df.drop(['Latitude', 'Longitude', 'Date'], axis = 1) #Removing Date, Latitude and Longitude and other extra columns
df_temp.style.background_gradient(cmap = 'Set3')
# Out:
# <style  type="text/css" >
#     #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row0_col1 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row0_col2 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row0_col3 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row0_col4 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row1_col1 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row1_col2 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row1_col3 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row1_col4 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row2_col1 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row2_col2 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row2_col3 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row2_col4 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row3_col1 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row3_col2 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row3_col3 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row3_col4 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row4_col1 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row4_col2 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row4_col3 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row4_col4 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row5_col1 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row5_col2 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row5_col3 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row5_col4 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row6_col1 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row6_col2 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row6_col3 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row6_col4 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row7_col1 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row7_col2 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row7_col3 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row7_col4 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row8_col1 {
#             background-color:  #80b1d3;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row8_col2 {
#             background-color:  #fb8072;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row8_col3 {
#             background-color:  #bebada;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row8_col4 {
#             background-color:  #fb8072;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row9_col1 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row9_col2 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row9_col3 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row9_col4 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row10_col1 {
#             background-color:  #ffffb3;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row10_col2 {
#             background-color:  #80b1d3;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row10_col3 {
#             background-color:  #fdb462;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row10_col4 {
#             background-color:  #bebada;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row11_col1 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row11_col2 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row11_col3 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row11_col4 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row12_col1 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row12_col2 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row12_col3 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row12_col4 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row13_col1 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row13_col2 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row13_col3 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row13_col4 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row14_col1 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row14_col2 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row14_col3 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row14_col4 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row15_col1 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row15_col2 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row15_col3 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row15_col4 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row16_col1 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row16_col2 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row16_col3 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row16_col4 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row17_col1 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row17_col2 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row17_col3 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row17_col4 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row18_col1 {
#             background-color:  #8dd3c7;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row18_col2 {
#             background-color:  #bebada;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row18_col3 {
#             background-color:  #ffffb3;
#         }    #T_cd1d49f8_a82d_11ea_988b_d481d7a00588row18_col4 {
#             background-color:  #ffffb3;
#         }    #T_cd1d49f8_a82d_11ea_988b_d48

# %%
total_cured = df['Cured'].sum()
print("Total number of people cured as of today are:", total_cured)

total_cases = df['Confirmed'].sum()
print("Total number of people found Corona +ve as of today are:", total_cases)

total_death = df['Deaths'].sum()
print("Total deaths due to Corona as of today are:", total_death)

total_active = total_cases - (total_cured + total_death)
print("Total active cases as of today are:", total_active)
# Out:
# Total number of people cured as of today are: 114073
# Total number of people found Corona +ve as of today are: 228465
# Total deaths due to Corona as of today are: 6642
# Total active cases as of today are: 107750

# %%
# Total Active cases = Total cases - (Number of death + Cured)

df['Total Active'] = df['Confirmed'] - (df['Deaths'] + df['Cured'])
total_active = df['Total Active'].sum()
print('Total number of active cases across India are:', total_active)

Tot_Cases = df.groupby('State/UT')['Total Active'].sum().sort_values(ascending = False).to_frame()

Tot_Cases.style.background_gradient(cmap = 'coolwarm')
# Out:
# Total number of active cases across India are: 107750
# <style  type="text/css" >
#     #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row0_col0 {
#             background-color:  #b40426;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row1_col0 {
#             background-color:  #b3cdfb;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row2_col0 {
#             background-color:  #9ebeff;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row3_col0 {
#             background-color:  #5e7de7;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row4_col0 {
#             background-color:  #5875e1;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row5_col0 {
#             background-color:  #5673e0;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row6_col0 {
#             background-color:  #506bda;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row7_col0 {
#             background-color:  #4e68d8;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row8_col0 {
#             background-color:  #4c66d6;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row9_col0 {
#             background-color:  #4b64d5;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row10_col0 {
#             background-color:  #4a63d3;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row11_col0 {
#             background-color:  #465ecf;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row12_col0 {
#             background-color:  #465ecf;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row13_col0 {
#             background-color:  #455cce;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row14_col0 {
#             background-color:  #445acc;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row15_col0 {
#             background-color:  #4257c9;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row16_col0 {
#             background-color:  #4055c8;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row17_col0 {
#             background-color:  #4055c8;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row18_col0 {
#             background-color:  #3e51c5;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row19_col0 {
#             background-color:  #3e51c5;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row20_col0 {
#             background-color:  #3d50c3;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row21_col0 {
#             background-color:  #3d50c3;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row22_col0 {
#             background-color:  #3c4ec2;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row23_col0 {
#             background-color:  #3b4cc0;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row24_col0 {
#             background-color:  #3b4cc0;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row25_col0 {
#             background-color:  #3b4cc0;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row26_col0 {
#             background-color:  #3b4cc0;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row27_col0 {
#             background-color:  #3b4cc0;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row28_col0 {
#             background-color:  #3b4cc0;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row29_col0 {
#             background-color:  #3b4cc0;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row30_col0 {
#             background-color:  #3b4cc0;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row31_col0 {
#             background-color:  #3b4cc0;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row32_col0 {
#             background-color:  #3b4cc0;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row33_col0 {
#             background-color:  #3b4cc0;
#         }    #T_cd4c495a_a82d_11ea_a83c_d481d7a00588row34_col0 {
#             background-color:  #3b4cc0;
#         }</style>
# <table id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Total Active</th>
#     </tr>    <tr>
#         <th class="index_name level0" >State/UT</th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588level0_row0" class="row_heading level0 row0" >Maharashtra</th>
#         <td id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588row0_col0" class="data row0 col0" >42224</td>
#     </tr>    <tr>
#         <th id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588level0_row1" class="row_heading level0 row1" >Delhi</th>
#         <td id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588row1_col0" class="data row1 col0" >15311</td>
#     </tr>    <tr>
#         <th id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588level0_row2" class="row_heading level0 row2" >Tamil Nadu</th>
#         <td id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588row2_col0" class="data row2 col0" >12700</td>
#     </tr>    <tr>
#         <th id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588level0_row3" class="row_heading level0 row3" >Gujarat</th>
#         <td id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588row3_col0" class="data row3 col0" >4901</td>
#     </tr>    <tr>
#         <th id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588level0_row4" class="row_heading level0 row4" >West Bengal</th>
#         <td id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588row4_col0" class="data row4 col0" >4025</td>
#     </tr>    <tr>
#         <th id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588level0_row5" class="row_heading level0 row5" >Uttar Pradesh</th>
#         <td id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588row5_col0" class="data row5 col0" >3828</td>
#     </tr>    <tr>
#         <th id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588level0_row6" class="row_heading level0 row6" >Karnataka</th>
#         <td id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588row6_col0" class="data row6 col0" >3090</td>
#     </tr>    <tr>
#         <th id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588level0_row7" class="row_heading level0 row7" >Madhya Pradesh</th>
#         <td id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588row7_col0" class="data row7 col0" >2734</td>
#     </tr>    <tr>
#         <th id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588level0_row8" class="row_heading level0 row8" >Rajasthan</th>
#         <td id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588row8_col0" class="data row8 col0" >2507</td>
#     </tr>    <tr>
#         <th id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588level0_row9" class="row_heading level0 row9" >Bihar</th>
#         <td id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588row9_col0" class="data row9 col0" >2342</td>
#     </tr>    <tr>
#         <th id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588level0_row10" class="row_heading level0 row10" >Jammu and Kashmir</th>
#         <td id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588row10_col0" class="data row10 col0" >2202</td>
#     </tr>    <tr>
#         <th id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588level0_row11" class="row_heading level0 row11" >Andhra Pradesh</th>
#         <td id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588row11_col0" class="data row11 col0" >1654</td>
#     </tr>    <tr>
#         <th id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588level0_row12" class="row_heading level0 row12" >Assam</th>
#         <td id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588row12_col0" class="data row12 col0" >1651</td>
#     </tr>    <tr>
#         <th id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588level0_row13" class="row_heading level0 row13" >Telengana</th>
#         <td id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588row13_col0" class="data row13 col0" >1550</td>
#     </tr>    <tr>
#         <th id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588level0_row14" class="row_heading level0 row14" >Haryana</th>
#         <td id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588row14_col0" class="data row14 col0" >1439</td>
#     </tr>    <tr>
#         <th id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588level0_row15" class="row_heading level0 row15" >Odisha</th>
#         <td id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588row15_col0" class="data row15 col0" >996</td>
#     </tr>    <tr>
#         <th id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588level0_row16" class="row_heading level0 row16" >Kerala</th>
#         <td id="T_cd4c495a_a82d_11ea_a83c_d481d7a00588row16_col0" clas

# %%
import numpy as np
state_cases = df_India.groupby('State/UT')['Confirmed','Deaths','Cured'].max().reset_index()

state_cases['Active'] = state_cases['Confirmed'] - (state_cases['Deaths'] + state_cases['Cured'])

state_cases["Death Rate (per 100)"] = np.round(100 * state_cases["Deaths"] / state_cases["Confirmed"], 2)

state_cases["Cure Rate (per 100)"] = np.round(100 * state_cases["Cured"] / state_cases["Confirmed"], 2)

state_cases.sort_values('Confirmed', ascending = False).fillna(0).style.background_gradient(cmap = 'gist_ncar_r', subset = ["Confirmed"])\
                        .background_gradient(cmap = 'gist_ncar_r', subset = ["Deaths"])\
                        .background_gradient(cmap = 'gist_ncar_r', subset = ["Cured"])\
                        .background_gradient(cmap = 'gist_ncar_r', subset = ["Active"])\
                        .background_gradient(cmap = 'gist_ncar_r', subset = ["Death Rate (per 100)"])\
                        .background_gradient(cmap = 'gist_ncar_r', subset = ["Cure Rate (per 100)"])
# Out:
# <style  type="text/css" >
#     #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row0_col1 {
#             background-color:  #000080;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row0_col2 {
#             background-color:  #000080;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row0_col3 {
#             background-color:  #000080;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row0_col4 {
#             background-color:  #000080;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row0_col5 {
#             background-color:  #89ff10;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row0_col6 {
#             background-color:  #ffe600;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row1_col1 {
#             background-color:  #ffa10b;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row1_col2 {
#             background-color:  #f09bf2;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row1_col3 {
#             background-color:  #ffeb00;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row1_col4 {
#             background-color:  #ff3400;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row1_col5 {
#             background-color:  #c256f7;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row1_col6 {
#             background-color:  #9fff24;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row2_col1 {
#             background-color:  #ff6805;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row2_col2 {
#             background-color:  #ff0047;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row2_col3 {
#             background-color:  #ff3000;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row2_col4 {
#             background-color:  #ffaa0c;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row2_col5 {
#             background-color:  #ffe100;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row2_col6 {
#             background-color:  #ffc908;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row3_col1 {
#             background-color:  #ff007c;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row3_col2 {
#             background-color:  #ffd801;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row3_col3 {
#             background-color:  #ffba0e;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row3_col4 {
#             background-color:  #da6ef2;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row3_col5 {
#             background-color:  #000080;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row3_col6 {
#             background-color:  #0dff0b;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row4_col1 {
#             background-color:  #c85cf5;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row4_col2 {
#             background-color:  #f0a0f2;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row4_col3 {
#             background-color:  #ff00f8;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row4_col4 {
#             background-color:  #f3b3f5;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row4_col5 {
#             background-color:  #ff8908;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row4_col6 {
#             background-color:  #00fa88;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row5_col1 {
#             background-color:  #ce62f4;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row5_col2 {
#             background-color:  #ee8df0;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row5_col3 {
#             background-color:  #ac29ff;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row5_col4 {
#             background-color:  #ee8df0;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row5_col5 {
#             background-color:  #ffdc00;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row5_col6 {
#             background-color:  #7ef804;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row6_col1 {
#             background-color:  #e074f1;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row6_col2 {
#             background-color:  #bc50f8;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row6_col3 {
#             background-color:  #b326ff;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row6_col4 {
#             background-color:  #f3aef4;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row6_col5 {
#             background-color:  #06ff15;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row6_col6 {
#             background-color:  #39e500;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row7_col1 {
#             background-color:  #ee8df0;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row7_col2 {
#             background-color:  #c85cf5;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row7_col3 {
#             background-color:  #ef97f1;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row7_col4 {
#             background-color:  #ed89ef;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row7_col5 {
#             background-color:  #00e9ff;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row7_col6 {
#             background-color:  #ffce05;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row8_col1 {
#             background-color:  #f3b3f5;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row8_col2 {
#             background-color:  #fae1fb;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row8_col3 {
#             background-color:  #f5c0f7;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row8_col4 {
#             background-color:  #f1a5f3;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row8_col5 {
#             background-color:  #dd11ff;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row8_col6 {
#             background-color:  #ff9109;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row9_col1 {
#             background-color:  #f4b7f5;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row9_col2 {
#             background-color:  #fdeffd;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row9_col3 {
#             background-color:  #f3aef4;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row9_col4 {
#             background-color:  #f4b7f5;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row9_col5 {
#             background-color:  #ec84ef;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row9_col6 {
#             background-color:  #edff10;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row10_col1 {
#             background-color:  #f5bcf6;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row10_col2 {
#             background-color:  #fadcfa;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row10_col3 {
#             background-color:  #f1a5f3;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row10_col4 {
#             background-color:  #f7caf8;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row10_col5 {
#             background-color:  #ff1300;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row10_col6 {
#             background-color:  #74e800;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row11_col1 {
#             background-color:  #f6c5f7;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row11_col2 {
#             background-color:  #fdeffd;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row11_col3 {
#             background-color:  #f3b3f5;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row11_col4 {
#             background-color:  #f8d3f9;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row11_col5 {
#             background-color:  #e67aef;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row11_col6 {
#             background-color:  #78ef00;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row12_col1 {
#             background-color:  #f7caf8;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row12_col2 {
#             background-color:  #fceafc;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row12_col3 {
#             background-color:  #f9d8fa;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row12_col4 {
#             background-color:  #f5bcf6;
#         }    #T_cd7cfc00_a82d_11ea_a108_d481d7a00588row12_col5
